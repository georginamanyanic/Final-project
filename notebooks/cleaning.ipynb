# %% [markdown]
# ### Cleaning Charactersitics Dataframe

# %%
import sys
sys.path.append('C:/Users/manya/Documents/Ironhack/Course/Final-project/src')
import cleaning
import pandas as pd
import json

# %%
df_characteristics = pd.read_csv('C:/Users/manya/Documents/Ironhack/Course/Final-project/data/characteristics.csv')
df_characteristics_cleaned = cleaning.cleaning_names(df_characteristics, 'name')
df_characteristics_cleaned = cleaning.column_cleaner(df_characteristics_cleaned)
df_characteristics_cleaned= df_characteristics_cleaned.to_csv('C:/Users/manya/Documents/Ironhack/Course/Final-project/data/characteristics_cleaned.csv')
# Out:
# C:\Users/manya/Documents/Ironhack/Course/Final-project/src\cleaning.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].replace('%2B', ' ').replace('%20(Globe)','').replace('%29', '').replace('~','/').replace('%28', '').rstrip()
# C:\Users/manya/Documents/Ironhack/Course/Final-project/src\cleaning.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].replace('%2B', ' ').replace('%20(Globe)','').replace('%29', '').replace('~','/').replace('%28', '').rstrip()
# ...

# %% [markdown]
# ### Cleaning DataFrame Seasonality

# %%
df_seasonality = pd.read_csv('C:/Users/manya/Documents/Ironhack/Course/Final-project/data/seasonality.csv')
df_seasonality.drop(columns = 'Unnamed: 0', inplace = True)
df_seasonality_cleaned = cleaning.cleaning_names(df_seasonality,'name')
# Out:
# C:\Users/manya/Documents/Ironhack/Course/Final-project/src\cleaning.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].replace('%2B', ' ').replace('%20(Globe)','').replace('%29', '').replace('~','/').replace('%28', '').rstrip()
# C:\Users/manya/Documents/Ironhack/Course/Final-project/src\cleaning.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].replace('%2B', ' ').replace('%20(Globe)','').replace('%29', '').replace('~','/').replace('%28', '').rstrip()
# ...

# %%
df_seasonality_cleaned
# Out:
#       Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec      name  \
# 0       S    S    S  NaN  NaN  NaN  NaN    S    S    S    S    S  Amaranth
# 1       T    T    T    T  NaN  NaN  NaN    T    T    T    T    T  Amaranth
# 2       P    P    P  NaN  NaN  NaN  NaN    P    P    P    P    P  Amaranth
# 3     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    S    S    S  Amaranth
# 4       T  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    T    T    T  Amaranth
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 7083    P  NaN  NaN  NaN  NaN  NaN  NaN    P    P    P    P    P  Zucchini
# 7084  NaN    P    P    P    P    P    P    P  NaN  NaN  NaN  NaN  Zucchini
# 7085  NaN  NaN  NaN  NaN  NaN  NaN  NaN    P    P    P    P  NaN  Zucchini
# 7086  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    S    S  NaN  NaN  Zucchini
# 7087  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    T    T  NaN  Zucchini
#
#       zone
# 0       17
# 1       17
# 2       17
# 3        1
# ...

# %% [markdown]
# Del Dataframe seasonality, solo nos quedamos con las zonas climáticas de USA ya que siguen el sistema de clasificación climática Hardiness zones que la podemos extrapolar a España mediante los archivos de la carpeta geojson que nos dan las coordenadas de lugares de españa según la zona climática.

# %%
"""Abrir el diccionario filtrado en formato json"""
with open('dict_climate_filtered.json', 'r') as file:
    dict_climate_filtered = json.load(file)

# %%
df_seasonality_cleaned = cleaning.filter_and_aggregate(df_seasonality_cleaned, 'zone', dict_climate_filtered)

# %%
#De la columna hardiness zone solo nos quedamos con el número y letra 
df_seasonality_cleaned['hardiness_zone'] = df_seasonality_cleaned['hardiness_zone'].apply(lambda i: i.split()[-1])

# %%
df_seasonality_cleaned= df_seasonality_cleaned.to_csv('C:/Users/manya/Documents/Ironhack/Course/Final-project/data/seasonality_cleaned.csv')

# %%
print(df_seasonality_cleaned)
# Out:
# None
