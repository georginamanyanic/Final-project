# %% [markdown]
# # Cleaning notebook

# %%
import pandas as pd 
import re 
import numpy as np

# %% [markdown]
# ### Cleaning Characteristics DataFrame

# %%
df_characteristics = pd.read_csv('C:/Users/manya/Documents/Ironhack/Course/Final-project/data/characteristics.csv')

# %%
df_characteristics.head(5)
# Out:
#    Unnamed: 0                  name  \
# 0           0              Amaranth
# 1           1              Angelica
# 2           2  Artichokes%20(Globe)
# 3           3             Asparagus
# 4           4       Asparagus%2BPea
#
#                                               sowing  \
# 0   Sow in garden. \t\t\t\tSow seed at a depth ap...
# 1   Easy to grow.  Sow in garden. \t\t\t\tSow see...
# 2   Easy to grow.  Sow in garden. \t\t\t\tSow see...
# 3   Easy to grow.  Plant as crowns. \n\t\t\t\tBes...
# 4   Easy to grow.  Sow in garden. \t\t\t\tSow see...
#
#                                      spacing  \
# 0         Space plants:  50  cm apart \t\t\t
# 1         Space plants:  45  cm apart \t\t\t
# 2  Space plants:  160 - 200  cm apart \t\t\t
# 3    Space plants:  20 - 40  cm apart \t\t\t
# 4    Space plants:  20 - 25  cm apart \t\t\t
#
#                                              harvest  \
# 0            \n\t\t\t\tHarvest in 7-8 weeks.\n\t\t\t
# ...

# %%
def cleaning_names (df, column):
    for i in range(len(df[column])):
        df[column][i] = df[column][i].replace('%2B', ' ').replace('%20(Globe)','').replace('%29', '').replace('~','/').replace('%28', '').rstrip()
    return df

df_characteristics_cleaned = cleaning_names (df_characteristics, 'name')
# Out:
# C:\Users\manya\AppData\Local\Temp\ipykernel_29720\3827629736.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].replace('%2B', ' ').replace('%20(Globe)','').replace('%29', '').replace('~','/').replace('%28', '').rstrip()
# C:\Users\manya\AppData\Local\Temp\ipykernel_29720\3827629736.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].replace('%2B', ' ').replace('%20(Globe)','').replace('%29', '').replace('~','/').replace('%28', '').rstrip()
# C:\Users\manya\AppData\Local\Temp\ipykernel_29720\3827629736.py:3: SettingWithCopyWarning:
# ...

# %% [markdown]
# #### Cleaning other columns

# %%
def column_cleaner (df):

    #Sowing column:
    df['sowing'] = df['sowing'].apply(lambda i: re.sub(r'\.\s+','. ',i))
    df['sowing'] = df['sowing'].apply(lambda i: i.replace('(Show °F/in) \n','').rstrip())
    df['temperature'] = df['sowing'].apply(lambda x: re.findall(r'\d+°C\s+and\s+\d+°C', x)[0]) #Creo una columna nueva
    df['sowing'] = df['sowing'].apply(lambda x: re.sub(r'\s+Best\s+planted\s+at\s+soil\s+temperatures\s+between\s+\d+°C\s+and\s+\d+°C\.', '', x))

    df['spacing'] = df['spacing'].apply(lambda i: re.sub(r'\s+',' ',i).split(':')[1])

    df['harvest'] = df['harvest'].apply(lambda i: re.sub(r'\s+',' ',i))

    df['compatibility'] = df['compatibility'].apply(lambda i: i.split(':')[1] if type(i)==str else np.nan )

    df['avoid'] = df['avoid'].apply(lambda i: i.split(':')[1] if type(i)==str else np.nan )

    df.drop(columns='Unnamed: 0', inplace = True)

    return df 

df_characteristics_cleaned=column_cleaner(df_characteristics_cleaned)

# %%
print(df_characteristics_cleaned.columns)
# Out:
# Index(['name', 'sowing', 'spacing', 'harvest', 'compatibility', 'avoid',
#        'image_link', 'temperature'],
#       dtype='object')

# %%
characteristics_cleaned = df_characteristics_cleaned.to_csv('C:/Users/manya/Documents/Ironhack/Course/Final-project/data/characteristics_cleaned.csv', index=False)

# %% [markdown]
# ## Cleaning Seasonality DataFrame

# %%
df_seasonality = pd.read_csv('C:/Users/manya/Documents/Ironhack/Course/Final-project/data/seasonality.csv')

# %%
df_seasonality.drop(columns = 'Unnamed: 0', inplace = True)
df_seasonality.name.unique()
# Out:
# array(['Amaranth', 'Angelica', 'Artichokes%20(Globe)', 'Asparagus',
#        'Asparagus%2BPea', 'Basil', 'Beans%2B-%2Bclimbing',
#        'Beans%2B-%2Bdwarf', 'Beetroot', 'Borage', 'Broad%2BBeans',
#        'Broccoli', 'Brussels%2Bsprouts', 'Burdock', 'Cabbage',
#        'Cape%2BGooseberry', 'Capsicum', 'Cardoon', 'Carrot',
#        'Cauliflower', 'Celeriac', 'Celery', 'Chicory', 'Chilli%2Bpeppers',
#        'Chinese%2Bcabbage', 'Chives', 'Choko~Chayote', 'Collards',
#        'Coriander', 'Corn%2BSalad', 'Cowpeas', 'Cucumber', 'Daikon',
#        'Dill', 'Eggplant', 'Endive', 'Fennel', 'Florence%2BFennel',
#        'French%2Btarragon', 'Garlic', 'Ginger', 'Horseradish',
#        'Jerusalem%2BArtichokes', 'Kale', 'Kohlrabi', 'Leeks',
#        'Lemon%2BBalm', 'Lettuce', 'Luffa', 'Marrow', 'Mint', 'Mizuna',
#        'Mustard%2Bgreens', 'NZ%2BSpinach', 'Okra', 'Onion', 'Oregano',
#        'Pak%2BChoy', 'Parsley', 'Parsnip', 'Peas', 'Potato', 'Pumpkin',
# ...

# %%
df_seasonality_cleaned = cleaning_names(df_seasonality,'name')
# Out:
# C:\Users\manya\AppData\Local\Temp\ipykernel_29720\3827629736.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].replace('%2B', ' ').replace('%20(Globe)','').replace('%29', '').replace('~','/').replace('%28', '').rstrip()
# C:\Users\manya\AppData\Local\Temp\ipykernel_29720\3827629736.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].replace('%2B', ' ').replace('%20(Globe)','').replace('%29', '').replace('~','/').replace('%28', '').rstrip()
# C:\Users\manya\AppData\Local\Temp\ipykernel_29720\3827629736.py:3: SettingWithCopyWarning:
# ...

# %%
df_seasonality_cleaned
# Out:
#       Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec      name  \
# 0       S    S    S  NaN  NaN  NaN  NaN    S    S    S    S    S  Amaranth
# 1       T    T    T    T  NaN  NaN  NaN    T    T    T    T    T  Amaranth
# 2       P    P    P  NaN  NaN  NaN  NaN    P    P    P    P    P  Amaranth
# 3     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    S    S    S  Amaranth
# 4       T  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    T    T    T  Amaranth
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 7083    P  NaN  NaN  NaN  NaN  NaN  NaN    P    P    P    P    P  Zucchini
# 7084  NaN    P    P    P    P    P    P    P  NaN  NaN  NaN  NaN  Zucchini
# 7085  NaN  NaN  NaN  NaN  NaN  NaN  NaN    P    P    P    P  NaN  Zucchini
# 7086  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    S    S  NaN  NaN  Zucchini
# 7087  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    T    T  NaN  Zucchini
#
#       zone
# 0       17
# 1       17
# 2       17
# 3        1
# ...

# %%
import sys
sys.path.append('C:/Users/manya/Documents/Ironhack/Course/Final-project/src')
import scrapping

# %%
scrapping.list_url
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 scrapping.list_url
#
# AttributeError: module 'scrapping' has no attribute 'list_url'
